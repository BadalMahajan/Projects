# %% [markdown]
# # DATA ANALYSIS BY BADAL

# %%
#importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing Dataset
df=pd.read_excel("Olympic_Athletes.xlsx")

# %%
df
# Out:
#                    Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 0           Michael Phelps  23.0  United States  2008            2008-08-24
# 1           Michael Phelps  19.0  United States  2004            2004-08-29
# 2           Michael Phelps  27.0  United States  2012            2012-08-12
# 3         Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4            Aleksey Nemov  24.0         Russia  2000            2000-10-01
# ...                    ...   ...            ...   ...                   ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
# ...

# %%
df.keys()
# Out:
# Index(['Athlete', 'Age', 'Country', 'Year', 'Closing_Ceremony_Date', 'Sport',
#        'Gold_Medals', 'Silver_Medals', 'Bronze_Medals', 'Total_Medals'],
#       dtype='object')

# %%
df.info() #Data information based on null values, data type, and count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Athlete                8613 non-null   object
#  1   Age                    8613 non-null   float64
#  2   Country                8618 non-null   object
#  3   Year                   8618 non-null   int64
#  4   Closing_Ceremony_Date  8618 non-null   datetime64[ns]
#  5   Sport                  8618 non-null   object
#  6   Gold_Medals            8618 non-null   int64
#  7   Silver_Medals          8618 non-null   int64
#  8   Bronze_Medals          8618 non-null   int64
#  9   Total_Medals           8618 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 673.4+ KB

# %%
df.head() # Head values of data
# Out:
#             Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
#
#         Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6

# %%
df.tail() # Last value of data
# Out:
#                    Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#         Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 8613  Archery            0              1              0             1
# 8614  Archery            0              1              0             1
# 8615  Archery            0              0              1             1
# 8616  Archery            0              0              1             1
# 8617  Archery            0              0              1             1

# %%
#Checking null values
df.isnull().sum()
# Out:
# Athlete                  5
# Age                      5
# Country                  0
# Year                     0
# Closing_Ceremony_Date    0
# Sport                    0
# Gold_Medals              0
# Silver_Medals            0
# Bronze_Medals            0
# Total_Medals             0
# dtype: int64

# %%
#Checking Datatypes of Columns
df.dtypes
# Out:
# Athlete                          object
# Age                             float64
# Country                          object
# Year                              int64
# Closing_Ceremony_Date    datetime64[ns]
# Sport                            object
# Gold_Medals                       int64
# Silver_Medals                     int64
# Bronze_Medals                     int64
# Total_Medals                      int64
# dtype: object

# %%
#droping null values from the dataset
data=df.dropna()

# %%
#Checking null values of new Dataset
data.isna().sum()
# Out:
# Athlete                  0
# Age                      0
# Country                  0
# Year                     0
# Closing_Ceremony_Date    0
# Sport                    0
# Gold_Medals              0
# Silver_Medals            0
# Bronze_Medals            0
# Total_Medals             0
# dtype: int64

# %%
#checking dupicates values
data.duplicated().sum()
# Out:
# 0

# %%
data.info() #Checking information of updated data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8613 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Athlete                8613 non-null   object
#  1   Age                    8613 non-null   float64
#  2   Country                8613 non-null   object
#  3   Year                   8613 non-null   int64
#  4   Closing_Ceremony_Date  8613 non-null   datetime64[ns]
#  5   Sport                  8613 non-null   object
#  6   Gold_Medals            8613 non-null   int64
#  7   Silver_Medals          8613 non-null   int64
#  8   Bronze_Medals          8613 non-null   int64
#  9   Total_Medals           8613 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 740.2+ KB

# %%
data.columns #data columns
# Out:
# Index(['Athlete', 'Age', 'Country', 'Year', 'Closing_Ceremony_Date', 'Sport',
#        'Gold_Medals', 'Silver_Medals', 'Bronze_Medals', 'Total_Medals'],
#       dtype='object')

# %%
# Checking total numbers of unique values of data
a=['Athlete', 'Age', 'Country', 'Year', 'Closing_Ceremony_Date', 'Sport','Gold_Medals', 'Silver_Medals', 'Bronze_Medals', 'Total_Medals']

for i in a:
    print(i,'=',data[i].nunique())
    print("Max=",data[i].max(),"Min=",data[i].min())#Highest and Lowest values of Columns
    print("")
# Out:
# Athlete = 6955
# Max= Živko Gocic Min= A. J. Mleczko
#
# Age = 42
# Max= 61.0 Min= 15.0
#
# Country = 110
# Max= Zimbabwe Min= Afghanistan
#
# Year = 7
# Max= 2012 Min= 2000
#
# Closing_Ceremony_Date = 7
# Max= 2012-08-12 00:00:00 Min= 2000-10-01 00:00:00
#
# Sport = 49
# Max= Wrestling Min= Alpine Skiing
#
# Gold_Medals = 7
# Max= 8 Min= 0
#
# Silver_Medals = 4
# Max= 3 Min= 0
#
# Bronze_Medals = 4
# Max= 3 Min= 0
#
# Total_Medals = 7
# Max= 8 Min= 1

# %%
data['Age'].value_counts().sort_index() #getting all those value exist in Age
# Out:
# 15.0     18
# 16.0     60
# 17.0     76
# 18.0    129
# 19.0    222
# 20.0    329
# 21.0    458
# 22.0    644
# 23.0    691
# 24.0    717
# 25.0    683
# 26.0    705
# 27.0    658
# 28.0    651
# 29.0    526
# 30.0    452
# 31.0    352
# 32.0    309
# 33.0    217
# 34.0    179
# 35.0    130
# 36.0    111
# 37.0     53
# 38.0     51
# 39.0     40
# 40.0     31
# 41.0     18
# 42.0     20
# 43.0     18
# 44.0     15
# 45.0     13
# 46.0     15
# 47.0      6
# 48.0      1
# 49.0      4
# 50.0      2
# 51.0      3
# 52.0      2
# 54.0      1
# 55.0      1
# 56.0      1
# 61.0      1
# Name: Age, dtype: int64

# %%
data['Country'].value_counts()
# Out:
# United States           1109
# Russia                   706
# Germany                  552
# Australia                524
# China                    450
#                         ...
# Uruguay                    1
# Macedonia                  1
# Gabon                      1
# United Arab Emirates       1
# Barbados                   1
# Name: Country, Length: 110, dtype: int64

# %%
data['Closing_Ceremony_Date'].value_counts()
# Out:
# 2008-08-24    1872
# 2000-10-01    1840
# 2004-08-29    1839
# 2012-08-12    1771
# 2006-02-26     443
# 2010-02-28     441
# 2002-02-24     407
# Name: Closing_Ceremony_Date, dtype: int64

# %%
data['Sport'].value_counts()
# Out:
# Athletics                    687
# Rowing                       567
# Swimming                     487
# Football                     407
# Hockey                       386
# Ice Hockey                   384
# Handball                     351
# Waterpolo                    306
# Canoeing                     295
# Basketball                   287
# Volleyball                   278
# Cycling                      261
# Wrestling                    245
# Fencing                      230
# Judo                         224
# Baseball                     216
# Sailing                      210
# Gymnastics                   194
# Boxing                       188
# Shooting                     181
# Weightlifting                180
# Equestrian                   157
# Softball                     134
# Cross Country Skiing         128
# Diving                       113
# Taekwondo                    112
# Synchronized Swimming        109
# Speed Skating                103
# ...

# %%
data['Athlete'].value_counts()
# Out:
# Matt Wells          4
# Jason Lezak         4
# Sergey Tetyukhin    4
# Leisel Jones        4
# Artur Taymazov      4
#                    ..
# Melanie Kok         1
# Jin Ziwei           1
# Michal Jelinski     1
# Josh Inman          1
# Rod White           1
# Name: Athlete, Length: 6955, dtype: int64

# %%
data['Athlete'].mode()
# Out:
# 0           Anky van Grunsven
# 1              Artur Taymazov
# 2                 Ben Ainslie
# 3             Bradley Wiggins
# 4                Brenda Villa
# 5                   Chris Hoy
# 6     Christie Pearce-Rampone
# 7              Emilie Heymans
# 8              Eskild Ebbesen
# 9               Heather Petri
# 10                Jason Lezak
# 11             Katalin Kovács
# 12         Katherine Grainger
# 13     Katrin Wagner-Augustin
# 14                  Kim Rhode
# 15            Kristi Harrower
# 16             Lauren Jackson
# 17               Leisel Jones
# 18                Lucha Aymar
# 19                 Matt Wells
# 20            Michal Martikán
# 21         Pavol Hochschorner
# 22         Peter Hochschorner
# 23             Robert Scheidt
# 24           Sergey Tetyukhin
# 25          Valentina Vezzali
# 26    Veronica Campbell-Brown
# 27                   Wang Hao
# 28                   Yang Wei
# Name: Athlete, dtype: object

# %%
data['Sport'].mode()
# Out:
# 0    Athletics
# Name: Sport, dtype: object

# %%
# Describing dataset
data.describe()
# Out:
#                Age         Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# count  8613.000000  8613.000000  8613.000000    8613.000000    8613.000000
# mean     26.405434  2005.975386     0.364914       0.362940       0.377917
# std       5.102118     4.288737     0.545436       0.511531       0.505069
# min      15.000000  2000.000000     0.000000       0.000000       0.000000
# 25%      23.000000  2002.000000     0.000000       0.000000       0.000000
# 50%      26.000000  2006.000000     0.000000       0.000000       0.000000
# 75%      29.000000  2010.000000     1.000000       1.000000       1.000000
# max      61.000000  2012.000000     8.000000       3.000000       3.000000
#
#        Total_Medals
# count   8613.000000
# mean       1.105770
# std        0.409003
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        8.000000

# %%
#Checking Correlation of data 
data.corr()
# Out:
#                     Age      Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Age            1.000000 -0.006814    -0.029553      -0.011229      -0.015306
# Year          -0.006814  1.000000    -0.002414      -0.001538       0.010084
# Gold_Medals   -0.029553 -0.002414     1.000000      -0.348641      -0.403291
# Silver_Medals -0.011229 -0.001538    -0.348641       1.000000      -0.445562
# Bronze_Medals -0.015306  0.010084    -0.403291      -0.445562       1.000000
# Total_Medals  -0.072357  0.007310     0.399522       0.235523       0.139806
#
#                Total_Medals
# Age               -0.072357
# Year               0.007310
# Gold_Medals        0.399522
# Silver_Medals      0.235523
# Bronze_Medals      0.139806
# Total_Medals       1.000000

# %%
sns.pairplot(data)

# %%
data.cov() #Checking covariance of data
# Out:
#                      Age       Year  Gold_Medals  Silver_Medals  \
# Age            26.031610  -0.149100    -0.082243      -0.029306
# Year           -0.149100  18.393263    -0.005648      -0.003374
# Gold_Medals    -0.082243  -0.005648     0.297501      -0.097274
# Silver_Medals  -0.029306  -0.003374    -0.097274       0.261664
# Bronze_Medals  -0.039443   0.021844    -0.111100      -0.115115
# Total_Medals   -0.150993   0.012822     0.089127       0.049276
#
#                Bronze_Medals  Total_Medals
# Age                -0.039443     -0.150993
# Year                0.021844      0.012822
# Gold_Medals        -0.111100      0.089127
# Silver_Medals      -0.115115      0.049276
# Bronze_Medals       0.255095      0.028880
# Total_Medals        0.028880      0.167283

# %%
#checking row value from one column
data[(data.Country == "India")]
# Out:
#                    Athlete   Age Country  Year Closing_Ceremony_Date  \
# 702         Yogeshwar Dutt  29.0   India  2012            2012-08-12
# 722           Sushil Kumar  29.0   India  2012            2012-08-12
# 797           Sushil Kumar  25.0   India  2008            2008-08-24
# 1094     Karnam Malleswari  25.0   India  2000            2000-10-01
# 2786           Vijay Kumar  26.0   India  2012            2012-08-12
# 2791          Gagan Narang  29.0   India  2012            2012-08-12
# 2807        Abhinav Bindra  25.0   India  2008            2008-08-24
# 2877  Rajyavardhan Rathore  34.0   India  2004            2004-08-29
# 7170        M. C. Mary Kom  29.0   India  2012            2012-08-12
# 7235        Vijender Singh  22.0   India  2008            2008-08-24
# 7806          Saina Nehwal  22.0   India  2012            2012-08-12
#
#               Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
# groupby all countries
data.groupby(["Country"]).sum()
# Out:
#                  Age     Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Country
# Afghanistan     46.0     4020            0              0              2
# Algeria        196.0    16028            2              2              4
# Argentina     3662.0   278832           49             32             58
# Armenia        240.0    20084            0              1              9
# Australia    13742.0  1050758          163            226            220
# ...              ...      ...          ...            ...            ...
# Uruguay         28.0     2000            0              1              0
# Uzbekistan     476.0    38116            5              4             10
# Venezuela      103.0     8028            1              0              3
# Vietnam         49.0     4008            0              2              0
# Zimbabwe        44.0     4012            2              4              1
#
#              Total_Medals
# Country
# Afghanistan             2
# ...

# %%
pd.crosstab(data['Athlete'],(data.Country=='India')).sum() #Total number of Athlete from India
# Out:
# Country
# False    8602
# True       11
# dtype: int64

# %%
data['Year'].nunique()
# Out:
# 7

# %%
data['Year'].values
# Out:
# array([2008, 2004, 2012, ..., 2000, 2000, 2000], dtype=int64)

# %%
pd.pivot_table(data,index=['Year','Age','Country'],aggfunc='sum') #Pivot table based on Year,Age,Country
# Out:
#                          Bronze_Medals  Gold_Medals  Silver_Medals  \
# Year Age  Country
# 2000 15.0 Australia                  0            0              2
#           China                      1            0              0
#           Greece                     1            0              0
#           Switzerland                0            0              1
#           United States              1            0              0
# ...                                ...          ...            ...
# 2012 51.0 Great Britain              0            0              1
#      52.0 Canada                     0            0              1
#           Great Britain              0            1              0
#      54.0 Great Britain              0            1              0
#      56.0 New Zealand                1            0              0
#
#                          Total_Medals
# Year Age  Country
# 2000 15.0 Australia                 2
#           China                     1
# ...

# %%
#pivot table by country
pd.pivot_table(data,index=['Country','Total_Medals'],aggfunc='max')
# Out:
#                            Age            Athlete  Bronze_Medals  \
# Country     Total_Medals
# Afghanistan 1             25.0    Rohullah Nikpai              1
# Algeria     1             29.0  Taoufik Makhloufi              1
# Argentina   1             46.0       Óscar Ustari              1
# Armenia     1             28.0    Yury Patrikeyev              1
# Australia   1             46.0     Yvette Higgins              1
# ...                        ...                ...            ...
# Uzbekistan  1             33.0  Yekaterina Khilko              1
# Venezuela   1             30.0      Rubén Limardo              1
# Vietnam     1             26.0     Tr?n Hi?u Ngân              0
# Zimbabwe    3             20.0    Kirsty Coventry              1
#             4             24.0    Kirsty Coventry              0
#
#                          Closing_Ceremony_Date  Gold_Medals  Silver_Medals  \
# Country     Total_Medals
# ...

# %%
plt.bar(data['Year'],data['Total_Medals'])
# Out:
# <BarContainer object of 8613 artists>

# %%
sns.boxplot(x="Age",data=data) # Checking Outliers by Boxplot
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data[(data['Sport']=='Wrestling')& (data.Year==2012)].sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                        Athlete   Age        Country  Year  \
# 697           Artur Aleksanyan  20.0        Armenia  2012
# 698         Valeriy Andriitsev  25.0        Ukraine  2012
# 749              S?rif S?rifov  23.0     Azerbaijan  2012
# 748             Mariya Stadnik  24.0     Azerbaijan  2012
# 747               Hamid Soryan  26.0           Iran  2012
# 746  Soronzonboldyn Battsetseg  22.0       Mongolia  2012
# 745          Mingiyan Semyonov  22.0         Russia  2012
# 744              Coleman Scott  26.0  United States  2012
# 743              Ghasem Rezaei  26.0           Iran  2012
# 742         Jackeline Rentería  26.0       Colombia  2012
#
#     Closing_Ceremony_Date      Sport  Gold_Medals  Silver_Medals  \
# 697            2012-08-12  Wrestling            0              0
# 698            2012-08-12  Wrestling            0              1
# 749            2012-08-12  Wrestling            1              0
# ...

# %%
data[(data['Sport']=='Swimming')& (data.Year==2012)].sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                 Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 2        Michael Phelps  27.0  United States  2012            2012-08-12
# 6        Missy Franklin  17.0  United States  2012            2012-08-12
# 7           Ryan Lochte  27.0  United States  2012            2012-08-12
# 8       Allison Schmitt  22.0  United States  2012            2012-08-12
# 5         Alicia Coutts  24.0      Australia  2012            2012-08-12
# 15             Sun Yang  20.0          China  2012            2012-08-12
# 42  Ranomi Kromowidjojo  21.0    Netherlands  2012            2012-08-12
# 48         Dana Vollmer  24.0  United States  2012            2012-08-12
# 47        Satomi Suzuki  21.0          Japan  2012            2012-08-12
# 46         Rebecca Soni  25.0  United States  2012            2012-08-12
#
#        Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 2   Swimming            4              2              0             6
# ...

# %%
data[(data.Age >38)& (data.Sport)].sort_values('Year')
# Out:
#                 Athlete   Age      Country  Year Closing_Ceremony_Date  \
# 8610    Barbara Mensing  39.0      Germany  2000            2000-10-01
# 6036     Angelo Mazzoni  39.0        Italy  2000            2000-10-01
# 6164       Ellen Bontje  42.0  Netherlands  2000            2000-10-01
# 2891  Sergey Alifirenko  41.0       Russia  2000            2000-10-01
# 2897   Svetlana Dyomina  39.0       Russia  2000            2000-10-01
# ...                 ...   ...          ...   ...                   ...
# 2964       Malcolm Page  40.0    Australia  2012            2012-08-12
# 2957       Fredrik Lööf  42.0       Sweden  2012            2012-08-12
# 6089      Peter Thomsen  51.0      Germany  2012            2012-08-12
# 6074     Marc Houtzager  41.0  Netherlands  2012            2012-08-12
# 6078   Andrew Nicholson  50.0  New Zealand  2012            2012-08-12
#
#            Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data[(data['Sport']=='Equestrian')&(data['Age']>38)].sort_values('Total_Medals',ascending=False)
# Out:
#                    Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 438           Heike Kemmer  46.0        Germany  2008            2008-08-24
# 448             Leslie Law  39.0  Great Britain  2004            2004-08-29
# 439            Eric Lamaze  40.0         Canada  2008            2008-08-24
# 453         Ulla Salzgeber  42.0        Germany  2000            2000-10-01
# 449         Ulla Salzgeber  46.0        Germany  2004            2004-08-29
# ...                    ...   ...            ...   ...                   ...
# 6099      Andreas Dibowski  42.0        Germany  2008            2008-08-24
# 6098              Mac Cone  55.0         Canada  2008            2008-08-24
# 6097     Nadine Capellmann  43.0        Germany  2008            2008-08-24
# 6096  Rolf-Göran Bengtsson  46.0         Sweden  2008            2008-08-24
# 6193          Albert Voorn  44.0    Netherlands  2000            2000-10-01
#
# ...

# %%
sns.lineplot(data['Age'],data['Total_Medals'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Total_Medals'>

# %%
data[(data.Age<20)& (data.Sport)].sort_values('Age')
# Out:
#                      Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 5353                Yang Yun  15.0          China  2000            2000-10-01
# 2118           Katie Ledecky  15.0  United States  2012            2012-08-12
# 3781      Kharikleia Pantazi  15.0         Greece  2000            2000-10-01
# 5345  Tasha Schwikert-Warren  15.0  United States  2000            2000-10-01
# 4434              Kim Martin  15.0         Sweden  2002            2002-02-24
# ...                      ...   ...            ...   ...                   ...
# 5239          Ihor Radivilov  19.0        Ukraine  2012            2012-08-12
# 1794             Lu Chunlong  19.0          China  2008            2008-08-24
# 1792                He Wenna  19.0          China  2008            2008-08-24
# 4140       Michelle Karvinen  19.0        Finland  2010            2010-02-28
# 1             Michael Phelps  19.0  United States  2004            2004-08-29
#
# ...

# %%
data[(data.Gold_Medals)& (data.Total_Medals==1)]
# Out:
#                 Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 700    Jordan Burroughs  24.0  United States  2012            2012-08-12
# 712          Kaori Icho  28.0          Japan  2012            2012-08-12
# 719       Alan Khugayev  23.0         Russia  2012            2012-08-12
# 720        Kim Hyeon-Wu  23.0    South Korea  2012            2012-08-12
# 728        Mijaín López  29.0           Cuba  2012            2012-08-12
# ...                 ...   ...            ...   ...                   ...
# 8600         Yun Mi-Jin  21.0    South Korea  2004            2004-08-29
# 8605  Simon Fairweather  30.0      Australia  2000            2000-10-01
# 8607       Jang Yong-Ho  24.0    South Korea  2000            2000-10-01
# 8609     Kim Cheong-Tae  20.0    South Korea  2000            2000-10-01
# 8611          O Gyo-Mun  28.0    South Korea  2000            2000-10-01
#
#           Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data[(data.Silver_Medals)& (data.Total_Medals==1)]
# Out:
#                  Athlete   Age      Country  Year Closing_Ceremony_Date  \
# 698   Valeriy Andriitsev  25.0      Ukraine  2012            2012-08-12
# 699      Rövs?n Bayramov  25.0   Azerbaijan  2012            2012-08-12
# 703        Jaime Espinal  27.0  Puerto Rico  2012            2012-08-12
# 705          Karam Gaber  32.0        Egypt  2012            2012-08-12
# 709      Sadegh Goudarzi  24.0         Iran  2012            2012-08-12
# ...                  ...   ...          ...   ...                   ...
# 8603   Nataliya Burdeina  26.0      Ukraine  2000            2000-10-01
# 8604       Ilario Di Buò  43.0        Italy  2000            2000-10-01
# 8606   Michele Frangilli  24.0        Italy  2000            2000-10-01
# 8613    Olena Sadovnycha  32.0      Ukraine  2000            2000-10-01
# 8614    Kateryna Serdiuk  17.0      Ukraine  2000            2000-10-01
#
#           Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data[(data.Bronze_Medals)& (data.Total_Medals==1)]
# Out:
#                    Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 697       Artur Aleksanyan  20.0        Armenia  2012            2012-08-12
# 701          Clarissa Chun  30.0  United States  2012            2012-08-12
# 702         Yogeshwar Dutt  29.0          India  2012            2012-08-12
# 704            Johan Eurén  27.0         Sweden  2012            2012-08-12
# 706      Daniyal Gadzhiyev  26.0     Kazakhstan  2012            2012-08-12
# ...                    ...   ...            ...   ...                   ...
# 8610       Barbara Mensing  39.0        Germany  2000            2000-10-01
# 8612        Cornelia Pfohl  29.0        Germany  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
# ...

# %%
data[(data.Gold_Medals)&(data.Total_Medals==3)&(data.Silver_Medals)&(data.Bronze_Medals)]
# Out:
#                    Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 43          Camille Muffat  22.0         France  2012            2012-08-12
# 49           Alain Bernard  25.0         France  2008            2008-08-24
# 67         Kirsty Coventry  20.0       Zimbabwe  2004            2004-08-29
# 68             Ian Crocker  21.0  United States  2004            2004-08-29
# 70          Brendan Hansen  22.0  United States  2004            2004-08-29
# 73            Leisel Jones  18.0      Australia  2004            2004-08-29
# 75          Laure Manaudou  17.0         France  2004            2004-08-29
# 77         Kaitlin Sandeno  21.0  United States  2004            2004-08-29
# 78         Roland Schoeman  24.0   South Africa  2004            2004-08-29
# 83   Massimiliano Rosolino  22.0          Italy  2000            2000-10-01
# 92               Wang Meng  20.0          China  2006            2006-02-26
# ...

# %%
data[data.Total_Medals==3]
# Out:
#                 Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 36        Nathan Adrian  23.0  United States  2012            2012-08-12
# 37        Yannick Agnel  20.0         France  2012            2012-08-12
# 38     Brittany Elmslie  18.0      Australia  2012            2012-08-12
# 39         Matt Grevers  27.0  United States  2012            2012-08-12
# 40         Ryosuke Irie  22.0          Japan  2012            2012-08-12
# ..                  ...   ...            ...   ...                   ...
# 149       Justin Gatlin  22.0  United States  2004            2004-08-29
# 150         Bode Miller  32.0  United States  2010            2010-02-28
# 151  Aksel Lund Svindal  27.0         Norway  2010            2010-02-28
# 152         Anja Pärson  24.0         Sweden  2006            2006-02-26
# 153  Stephan Eberharter  32.0        Austria  2002            2002-02-24
#
#              Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data[data.Country=='India'].sort_values('Gold_Medals',ascending=False)
# Out:
#                    Athlete   Age Country  Year Closing_Ceremony_Date  \
# 2807        Abhinav Bindra  25.0   India  2008            2008-08-24
# 702         Yogeshwar Dutt  29.0   India  2012            2012-08-12
# 722           Sushil Kumar  29.0   India  2012            2012-08-12
# 797           Sushil Kumar  25.0   India  2008            2008-08-24
# 1094     Karnam Malleswari  25.0   India  2000            2000-10-01
# 2786           Vijay Kumar  26.0   India  2012            2012-08-12
# 2791          Gagan Narang  29.0   India  2012            2012-08-12
# 2877  Rajyavardhan Rathore  34.0   India  2004            2004-08-29
# 7170        M. C. Mary Kom  29.0   India  2012            2012-08-12
# 7235        Vijender Singh  22.0   India  2008            2008-08-24
# 7806          Saina Nehwal  22.0   India  2012            2012-08-12
#
#               Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data.groupby(['Country']).sum().sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                    Age     Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Country
# United States  28932.0  2224716          552            440            320
# Russia         18177.0  1415868          234            221            313
# Germany        15119.0  1107088          223            183            223
# Australia      13742.0  1050758          163            226            220
# China          10675.0   903092          234            156            140
# Canada          9800.0   704354          168             98            104
# Italy           8644.0   615684           86            103            142
# Great Britain   8300.0   594160          124            101             97
# France          7758.0   575808          108            107            103
# Netherlands     7723.0   573688          101            135             82
#
#                Total_Medals
# Country
# United States          1312
# Russia                  768
# Germany                 629
# ...

# %%
data[data.Year==2010].groupby(['Country']).sum().sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                   Age    Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Country
# United States  2117.0  168840           12             63             22
# Canada         2391.0  172860           67             15              8
# Germany        1185.0   86430           15             24             15
# Finland        1272.0   92460            0              1             46
# Norway          764.0   54270           16             14              9
# Austria         574.0   42210           11              9              6
# Russia          583.0   44220            6              5             14
# China           416.0   32160            9              3              7
# Sweden          399.0   26130           11              3              4
# South Korea     220.0   22110            6             10              2
#
#                Total_Medals
# Country
# United States            97
# Canada                   90
# Germany                  54
# Finland                  47
# ...

# %%
data[data.Age>30].groupby(['Country']).sum().sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                   Age    Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Country
# United States  6709.0  389068           87             66             61
# Germany        4436.0  254706           57             53             38
# Russia         3537.0  210502           29             36             49
# Italy          3391.0  198572           28             38             40
# Canada         3356.0  188616           41             30             26
# Great Britain  2871.0  164586           36             32             24
# Australia      2978.0  176422           16             39             35
# France         1917.0  114336           29             13             17
# Netherlands    1691.0   98330           15             28             13
# Sweden         1827.0  104324           24             24              6
#
#                Total_Medals
# Country
# United States           214
# Germany                 148
# Russia                  114
# Italy                   106
# ...

# %%
data[data.Gold_Medals>=1].groupby(['Country']).sum().sort_values('Total_Medals',ascending=False).head(10)
# Out:
#                    Age    Year  Gold_Medals  Silver_Medals  Bronze_Medals  \
# Country
# United States  12934.0  995036          552             62             45
# China           4788.0  411342          234             22             17
# Russia          5604.0  447246          234             15             16
# Germany         5851.0  415296          223             25             11
# Australia       3721.0  290618          163             27             13
# Canada          4533.0  333054          168              5              6
# Great Britain   3217.0  228816          124              6              4
# South Korea     2417.0  202692          110             15              4
# France          2927.0  210680          108             10              6
# Netherlands     2490.0  188630          101              9              8
#
#                Total_Medals
# Country
# United States           659
# China                   273
# Russia                  265
# ...

# %%
data[(data.Age<20)].head(10).sort_values('Total_Medals',ascending=False).head(10)
# Out:
#              Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 1     Michael Phelps  19.0  United States  2004            2004-08-29
# 6     Missy Franklin  17.0  United States  2012            2012-08-12
# 10        Ian Thorpe  17.0      Australia  2000            2000-10-01
# 13     Nastia Liukin  18.0  United States  2008            2008-08-24
# 29   Aliya Mustafina  17.0         Russia  2012            2012-08-12
# 30     Shawn Johnson  16.0  United States  2008            2008-08-24
# 38  Brittany Elmslie  18.0      Australia  2012            2012-08-12
# 53        Katie Hoff  19.0  United States  2008            2008-08-24
# 73      Leisel Jones  18.0      Australia  2004            2004-08-29
# 75    Laure Manaudou  17.0         France  2004            2004-08-29
#
#          Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 1     Swimming            6              0              2             8
# ...

# %%
data[data.Athlete=='Leisel Jones']
# Out:
#            Athlete   Age    Country  Year Closing_Ceremony_Date     Sport  \
# 54    Leisel Jones  22.0  Australia  2008            2008-08-24  Swimming
# 73    Leisel Jones  18.0  Australia  2004            2004-08-29  Swimming
# 267   Leisel Jones  15.0  Australia  2000            2000-10-01  Swimming
# 2110  Leisel Jones  26.0  Australia  2012            2012-08-12  Swimming
#
#       Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 54              2              1              0             3
# 73              1              1              1             3
# 267             0              2              0             2
# 2110            0              1              0             1

# %%
data[data.Sport=='Athletics']
# Out:
#                       Athlete   Age         Country  Year  \
# 142               Yohan Blake  22.0         Jamaica  2012
# 143                Usain Bolt  25.0         Jamaica  2012
# 144             Allyson Felix  26.0   United States  2012
# 145   Shelly-Ann Fraser-Pryce  25.0         Jamaica  2012
# 146           Carmelita Jeter  32.0   United States  2012
# ...                       ...   ...             ...   ...
# 8503          Yelena Yelesina  30.0          Russia  2000
# 8504              Jan Železný  34.0  Czech Republic  2000
# 8505        Szymon Ziólkowski  24.0          Poland  2000
# 8506           Ellina Zvereva  39.0         Belarus  2000
# 8507            Olesya Zykina  19.0          Russia  2000
#
#      Closing_Ceremony_Date      Sport  Gold_Medals  Silver_Medals  \
# 142             2012-08-12  Athletics            1              2
# 143             2012-08-12  Athletics            3              0
# 144             2012-08-12  Athletics            3              0
# ...

# %%
data[data.Athlete=='Anky van Grunsven']
# Out:
#                 Athlete   Age      Country  Year Closing_Ceremony_Date  \
# 442   Anky van Grunsven  40.0  Netherlands  2008            2008-08-24
# 454   Anky van Grunsven  32.0  Netherlands  2000            2000-10-01
# 6093  Anky van Grunsven  44.0  Netherlands  2012            2012-08-12
# 6155  Anky van Grunsven  36.0  Netherlands  2004            2004-08-29
#
#            Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# 442   Equestrian            1              1              0             2
# 454   Equestrian            1              1              0             2
# 6093  Equestrian            0              0              1             1
# 6155  Equestrian            1              0              0             1

# %%
pd.crosstab(data.Year,data.Total_Medals)
# Out:
# Total_Medals     1    2   3  4  5  6  8
# Year
# 2000          1712  106  11  8  2  1  0
# 2002           352   41  12  2  0  0  0
# 2004          1711  101  22  3  1  0  1
# 2006           381   44  16  1  1  0  0
# 2008          1737  106  22  4  1  1  1
# 2010           380   46  13  1  1  0  0
# 2012          1643   99  22  2  4  1  0

# %%
pd.crosstab(data.Year,data.Gold_Medals)
# Out:
# Gold_Medals     0    1   2  3  4  6  8
# Year
# 2000         1225  572  38  5  0  0  0
# 2002          262  132  10  2  1  0  0
# 2004         1208  605  21  4  0  1  0
# 2006          285  143  12  3  0  0  0
# 2008         1244  595  28  4  0  0  1
# 2010          281  148  10  2  0  0  0
# 2012         1184  550  31  4  2  0  0

# %%
pd.crosstab(data.Year,data.Silver_Medals)
# Out:
# Silver_Medals     0    1   2  3
# Year
# 2000           1207  606  26  1
# 2002            257  143   7  0
# 2004           1194  629  16  0
# 2006            278  156   8  1
# 2008           1230  621  16  5
# 2010            279  150  11  1
# 2012           1164  586  20  1

# %%
pd.crosstab(data.Year,data.Bronze_Medals)
# Out:
# Bronze_Medals     0    1   2  3
# Year
# 2000           1170  661   7  2
# 2002            253  150   3  1
# 2004           1175  651  12  1
# 2006            279  153  11  0
# 2008           1182  670  19  1
# 2010            279  153   9  0
# 2012           1101  660  10  0

# %%
pd.crosstab(data.Closing_Ceremony_Date,data.Total_Medals)
# Out:
# Total_Medals              1    2   3  4  5  6  8
# Closing_Ceremony_Date
# 2000-10-01             1712  106  11  8  2  1  0
# 2002-02-24              352   41  12  2  0  0  0
# 2004-08-29             1711  101  22  3  1  0  1
# 2006-02-26              381   44  16  1  1  0  0
# 2008-08-24             1737  106  22  4  1  1  1
# 2010-02-28              380   46  13  1  1  0  0
# 2012-08-12             1643   99  22  2  4  1  0

# %%
data.sort_values('Year')
# Out:
#                Athlete   Age        Country  Year Closing_Ceremony_Date  \
# 8617         Rod White  23.0  United States  2000            2000-10-01
# 2318      Amanda Beard  18.0  United States  2000            2000-10-01
# 2319     B. J. Bedford  27.0  United States  2000            2000-10-01
# 2320     Lindsay Benko  23.0  United States  2000            2000-10-01
# 2321         Kim Black  21.0  United States  2000            2000-10-01
# ...                ...   ...            ...   ...                   ...
# 5455       Bruno Uvini  21.0         Brazil  2012            2012-08-12
# 5454    Brittany Timko  26.0         Canada  2012            2012-08-12
# 5453  Melissa Tancredi  30.0         Canada  2012            2012-08-12
# 1168       Josip Pavic  30.0        Croatia  2012            2012-08-12
# 7193      Katie Taylor  26.0        Ireland  2012            2012-08-12
#
#           Sport  Gold_Medals  Silver_Medals  Bronze_Medals  Total_Medals
# ...

# %%
data[(data['Year']==2002)&(data.Total_Medals>=1)].count()
# Out:
# Athlete                  407
# Age                      407
# Country                  407
# Year                     407
# Closing_Ceremony_Date    407
# Sport                    407
# Gold_Medals              407
# Silver_Medals            407
# Bronze_Medals            407
# Total_Medals             407
# dtype: int64

# %%
data['Total_Medals'].sum()
# Out:
# 9524
